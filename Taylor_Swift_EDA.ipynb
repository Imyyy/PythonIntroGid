# %% [markdown]
# <a href="https://colab.research.google.com/github/Imyyy/PythonIntroGid/blob/main/Taylor_Swift_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Info
#
#
#
# AIM: Develop a session that  builds on previously introduced concepts (dataframes, pandas, pulling out statistics), and lets young people play around with answering their own questions about data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# %% [markdown]
# ## Dataset 1
# ### EDA
# Data: https://www.kaggle.com/datasets/arthurboari/taylor-swift-spotify-data?resource=download

# %%
# files.upload()

# %%
d1 = pd.read_csv("Taylor Swift Spotify Data.csv")

d1.head(2)
# Out:
#     artist_name               artist_id                album_id album_type  \
# 0  Taylor Swift  06HL4z0CvFAxyc27GXpf02  3lS1y25WAhcqJDATJK70Mq      album
# 1  Taylor Swift  06HL4z0CvFAxyc27GXpf02  3lS1y25WAhcqJDATJK70Mq      album
#
#   album_release_date  album_release_year album_release_date_precision  \
# 0         2022-10-22                2022                          day
# 1         2022-10-22                2022                          day
#
#    danceability  energy  key  ...     track_name  track_preview_url  \
# 0         0.735   0.444   10  ...  Lavender Haze                NaN
# 1         0.658   0.378    7  ...         Maroon                NaN
#
#    track_number   type                             track_uri  \
# 0             1  track  spotify:track:4g2c7NoTWAOSYDy44l9nub
# 1             2  track  spotify:track:199E1RRrVmVTQqBXih5qRC
#
#                                external_urls.spotify               album_name  \
# ...

# %%
albums = list(d1['album_name'].unique())
albums.sort()
for a in albums:
  print(a)
# Out:
# 1989
# 1989 (Big Machine Radio Release Special)
# 1989 (Deluxe Edition)
# 1989 (Deluxe)
# Fearless
# Fearless (Big Machine Radio Release Special)
# Fearless (International Version)
# Fearless (Karaoke Version)
# Fearless (Platinum Edition)
# Fearless (Taylor's Version)
# Fearless Karaoke
# Fearless Platinum Edition
# Live From Clear Channel Stripped 2008
# Lover
# Midnights
# Midnights (3am Edition)
# Red
# Red (Big Machine Radio Release Special)
# Red (Deluxe Edition)
# Red (Karaoke Version)
# Red (Taylor's Version)
# Speak Now
# Speak Now (Big Machine Radio Release Special)
# Speak Now (Deluxe Edition)
# Speak Now (Deluxe Package)
# Speak Now (Japanese Version)
# Speak Now (Karaoke Version)
# Speak Now (US Version)
# Speak Now World Tour Live
# Taylor Swift
# Taylor Swift (Big Machine Radio Release Special)
# Taylor Swift (Karaoke Version)
# Taylor Swift Karaoke
# Taylor Swift Karaoke: 1989
# Taylor Swift Karaoke: 1989 (Deluxe Edition)
# Taylor Swift Karaoke: 1989 (Deluxe)
# ...

# %%
# Filter down to just one of each album
albums_wanted = ["1989", "Fearless", "Lover", "Midnights", "Red", "Speak Now", "Taylor Swift", "evermore", "folklore", "reputation"]
data = d1[d1['album_name'].isin(albums_wanted)]
data.head()
# No TTPD
# Out:
#      artist_name               artist_id                album_id album_type  \
# 40  Taylor Swift  06HL4z0CvFAxyc27GXpf02  151w1FgRZfnKZA9FEcg9Z3      album
# 41  Taylor Swift  06HL4z0CvFAxyc27GXpf02  151w1FgRZfnKZA9FEcg9Z3      album
# 42  Taylor Swift  06HL4z0CvFAxyc27GXpf02  151w1FgRZfnKZA9FEcg9Z3      album
# 43  Taylor Swift  06HL4z0CvFAxyc27GXpf02  151w1FgRZfnKZA9FEcg9Z3      album
# 44  Taylor Swift  06HL4z0CvFAxyc27GXpf02  151w1FgRZfnKZA9FEcg9Z3      album
#
#    album_release_date  album_release_year album_release_date_precision  \
# 40         2022-10-21                2022                          day
# 41         2022-10-21                2022                          day
# 42         2022-10-21                2022                          day
# 43         2022-10-21                2022                          day
# 44         2022-10-21                2022                          day
#
#     danceability  energy  key  ...                              track_name  \
# ...

# %%
# Check for track duplication
a = data.track_name.value_counts()
print(a)  # Therefore we have some track duplication

# Need to dedupe track name
# Out:
# track_name
# The Way I Loved You                       4
# Love Story                                4
# Our Song                                  4
# Change                                    4
# The Best Day                              4
#                                          ..
# Sad Beautiful Tragic - Karaoke Version    1
# Holy Ground - Karaoke Version             1
# The Last Time - Karaoke Version           1
# Stay Stay Stay - Karaoke Version          1
# Starlight                                 1
# Name: count, Length: 170, dtype: int64

# %% [markdown]
# ## Q1: Which album is best to dance to?

# %%
plt.bar(height=d1['danceability'], x =d1['album_name'])
plt.xticks(rotation=90)
plt.show()
